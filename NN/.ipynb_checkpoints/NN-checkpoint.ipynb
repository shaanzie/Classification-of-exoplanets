# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('../new_data.csv')

# %%
dataset.shape
# Out:
# (3875, 65)

# %%
from sklearn.preprocessing import StandardScaler

# %%
features=[]
for i in dataset.select_dtypes(include=['float64']):
    features.append(i)
features
# Out:
# ['P. Min Mass (EU)',
#  'P. Mass (EU)',
#  'P. Max Mass (EU)',
#  'P. Radius (EU)',
#  'P. Density (EU)',
#  'P. Gravity (EU)',
#  'P. Esc Vel (EU)',
#  'P. Teq Min (K)',
#  'P. Teq Mean (K)',
#  'P. Teq Max (K)',
#  'P. Ts Min (K)',
#  'P. Ts Mean (K)',
#  'P. Ts Max (K)',
#  'P. Surf Press (EU)',
#  'P. Mag',
#  'P. Appar Size (deg)',
#  'P. Period (days)',
#  'P. Sem Major Axis (AU)',
#  'P. Eccentricity',
#  'P. Mean Distance (AU)',
#  'P. Inclination (deg)',
#  'P. Omega (deg)',
#  'S. Mass (SU)',
#  'S. Radius (SU)',
#  'S. Teff (K)',
#  'S. Luminosity (SU)',
#  'S. [Fe/H]',
#  'S. Age (Gyrs)',
#  'S. Appar Mag',
#  'S. Distance (pc)',
#  'S. RA (hrs)',
#  'S. DEC (deg)',
#  'S. Mag from Planet',
#  'S. Size from Planet (deg)',
#  'S. Hab Zone Min (AU)',
#  'S. Hab Zone Max (AU)',
#  'P. HZD',
#  'P. HZC',
#  'P. HZA',
#  'P. HZI',
#  'P. SPH',
#  'P. ESI']

# %%
X = dataset.loc[:,features].values

# %%
y = dataset.loc[:,['P. Zone Class']].values

# %%
X = StandardScaler().fit_transform(X)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(.95)

# %%
principalComponents = pca.fit_transform(X)

# %%
principalDf = pd.DataFrame(data = principalComponents)

# %%
principalDf
# Out:
#             0         1         2         3         4         5         6   \
# 0     7.406941 -2.236364  1.108121 -1.503311  3.056849  0.452301 -0.405917
# 1     6.435049 -1.453287  2.319839 -0.831350 -0.872154  0.401785 -1.268623
# 2     7.115703 -3.453432  1.888106 -1.197222  1.379326 -1.056392 -1.954168
# 3     7.265277 -3.281429  2.333421 -1.211137  0.891057 -0.688281 -1.914103
# 4     7.733121 -3.694203  1.547577 -1.967529  3.038381 -0.872574 -2.290104
# ...        ...       ...       ...       ...       ...       ...       ...
# 3870  1.000425  1.305993 -1.063578 -1.086470 -0.234611 -0.888069  0.403105
# 3871  1.477355  1.686243 -1.382635 -1.158704 -0.595408 -2.407142  0.581682
# 3872 -0.920209 -2.800432 -0.513861 -0.200527 -0.242215 -1.522808 -0.227844
# 3873 -0.805979 -3.210689 -0.734928 -0.013543 -0.391567 -1.707660 -0.070091
# 3874 -0.738739 -3.631693 -0.953756  0.219520 -0.604484 -2.099862  0.126465
#
#             7         8         9   ...        11        12        13  \
# 0    -1.844187 -1.304643 -0.006507  ... -0.262278  0.109953  2.133475
# 1    -0.554578 -1.304376 -0.788641  ... -0.076826 -0.392422  0.555927
# 2    -1.766280 -1.495629  0.686886  ... -0.158270 -1.143645  1.640642
# 3    -1.622248 -0.915576  0.689988  ... -0.144466 -1.065006  1.637137
# 4    -1.585455 -1.149877  1.384476  ... -0.157676 -1.231699  2.188842
# ...        ...       ...       ...  ...       ...       ...       ...
# 3870 -0.182172  0.411499 -0.149428  ...  0.129145 -0.230230  0.881986
# 3871  0.240067  0.252042 -0.181252  ...  0.637365 -0.709286 -0.036438
# 3872  0.344207 -0.675990  2.302768  ... -1.722026 -0.496225  2.149744
# 3873  0.461881 -0.543770  2.348907  ... -1.629429 -0.630901  2.142431
# 3874  0.640621 -0.410195  2.415944  ... -1.479354 -0.858259  2.050809
#
#             15        16        17        18        19        20  \
# 0    -0.950246 -1.158124 -1.195811  0.418113 -0.533408 -1.364633
# 1     0.242721 -0.731670 -0.525099 -0.851763 -0.471775 -1.802242
# 2    -1.260898 -0.811908 -0.637260  0.612861 -0.463602 -0.479314
# 3    -1.639507 -1.499087 -1.009182  0.678738 -0.448969 -0.255845
# 4    -1.982734 -1.679862 -0.589995  0.809750 -0.591533 -0.415230
# ...        ...       ...       ...       ...       ...       ...
# 3870 -0.256277 -0.027782  0.950000 -1.244613 -0.936427  0.618385
# 3871 -0.565869  0.216909  1.798142 -2.086564  0.115397  1.098094
# 3872 -0.420205  0.539222 -0.324162  0.031832 -0.438642 -0.085208
# 3873 -0.201998  0.441376 -0.235914  0.118591 -0.488319 -0.057853
# 3874  0.142359  0.342970 -0.013723  0.255715 -0.702965  0.069814
#
#       P. Habitable Class
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 3870                   1
# 3871                   1
# 3872                   1
# 3873                   1
# 3874                   1
#
# [3875 rows x 22 columns]

# %%
data_final = principalDf.values

# %%
data_final
# Out:
# array([[7.40694086433324, -2.236364262607035, 1.1081208605521473, ...,
#         -0.5334081675340449, -1.3646325956247698, '1'],
#        [6.435048983507719, -1.4532866324583753, 2.3198394061286334, ...,
#         -0.471774835310599, -1.8022420342078729, '1'],
#        [7.115703479829679, -3.4534322951504177, 1.8881063987572457, ...,
#         -0.4636022142212306, -0.47931356935343494, '1'],
#        ...,
#        [-0.9202090017456361, -2.800431902949775, -0.5138611335289784,
#         ..., -0.43864234998288054, -0.08520816660040394, '1'],
#        [-0.805978733532147, -3.210689487665826, -0.7349277097559459, ...,
#         -0.4883193007244602, -0.057853405910705445, '1'],
#        [-0.7387388710184594, -3.631693111459361, -0.9537558065070404,
#         ..., -0.7029654110490448, 0.06981410681796459, '1']], dtype=object)

# %%
X = data_final[:,0:21]
Y = data_final[:,21]

# %%
from sklearn import preprocessing 
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.62908409, 0.31815658, 0.10823601, ..., 0.50495303, 0.41787968,
#         0.20360698],
#        [0.60503723, 0.347909  , 0.14093266, ..., 0.39018068, 0.42611305,
#         0.14505542],
#        [0.6218782 , 0.27191502, 0.12928291, ..., 0.52255451, 0.4272048 ,
#         0.3220615 ],
#        ...,
#        [0.42305104, 0.29672526, 0.06446894, ..., 0.47004068, 0.4305391 ,
#         0.37479229],
#        [0.42587737, 0.28113784, 0.05850374, ..., 0.47788201, 0.42390294,
#         0.37845232],
#        [0.42754104, 0.26514214, 0.05259895, ..., 0.49027538, 0.39522915,
#         0.39553406]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (2712, 21) (581, 21) (582, 21) (2712,) (581,) (582,)

# %%
Y
# Out:
# array(['1', '1', '1', ..., '1', '1', '1'], dtype=object)

# %%
# !pip3 
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-b9e2c8277ae4> in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense
#
# ~/.local/lib/python3.6/site-packages/keras/__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~/.local/lib/python3.6/site-packages/keras/utils/__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7 from . import losses_utils
#       8 from . import metrics_utils
#
# ~/.local/lib/python3.6/site-packages/keras/utils/conv_utils.py in <module>
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# ~/.local/lib/python3.6/site-packages/keras/backend/__init__.py in <module>
# ----> 1 from .load_backend import epsilon
#       2 from .load_backend import set_epsilon
#       3 from .load_backend import floatx
#       4 from .load_backend import set_floatx
#       5 from .load_backend import cast_to_floatx
#
# ~/.local/lib/python3.6/site-packages/keras/backend/load_backend.py in <module>
#      88 elif _BACKEND == 'tensorflow':
#      89     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 90     from .tensorflow_backend import *
#      91 else:
#      92     # Try and load external backend.
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in <module>
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.eager import context
#       7 from tensorflow.python.framework import device as tfdev
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
model = Sequential([Dense(35,activation='sigmoid',input_shape=(21,)),
                    Dense(36,activation='sigmoid'),
                    Dense(37,activation='sigmoid'),
                    Dense(38,activation='sigmoid'),
                    Dense(39,activation='sigmoid'),
                    Dense(1,activation='sigmoid'),])

# %%
from keras import optimizers
adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.990, amsgrad=False)
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist=model.fit(X_train,Y_train,
               batch_size=2712,epochs=25)
# Out:
# Epoch 1/25
# 2712/2712 [==============================] - 0s 14us/step - loss: 0.7128 - acc: 0.0144
# Epoch 2/25
# 2712/2712 [==============================] - 0s 15us/step - loss: 0.6140 - acc: 0.0892
# Epoch 3/25
# 2712/2712 [==============================] - 0s 16us/step - loss: 0.5165 - acc: 0.0892
# Epoch 4/25
# 2712/2712 [==============================] - 0s 16us/step - loss: 0.4201 - acc: 0.0892
# Epoch 5/25
# 2712/2712 [==============================] - 0s 14us/step - loss: 0.3250 - acc: 0.0892
# Epoch 6/25
# 2712/2712 [==============================] - 0s 15us/step - loss: 0.2312 - acc: 0.0892
# Epoch 7/25
# 2712/2712 [==============================] - 0s 14us/step - loss: 0.1387 - acc: 0.0892
# Epoch 8/25
# 2712/2712 [==============================] - 0s 16us/step - loss: 0.0475 - acc: 0.0892
# Epoch 9/25
# 2712/2712 [==============================] - 0s 14us/step - loss: -0.0425 - acc: 0.0892
# Epoch 10/25
# 2712/2712 [==============================] - 0s 14us/step - loss: -0.1311 - acc: 0.0892
# Epoch 11/25
# 2712/2712 [==============================] - 0s 15us/step - loss: -0.2185 - acc: 0.0892
# Epoch 12/25
# 2712/2712 [==============================] - 0s 14us/step - loss: -0.3046 - acc: 0.0892
# Epoch 13/25
# 2712/2712 [==============================] - 0s 15us/step - loss: -0.3895 - acc: 0.0892
# Epoch 14/25
# 2712/2712 [==============================] - 0s 14us/step - loss: -0.4732 - acc: 0.0892
# Epoch 15/25
# 2712/2712 [==============================] - 0s 15us/step - loss: -0.5558 - acc: 0.0892
# Epoch 16/25
# 2712/2712 [==============================] - 0s 15us/step - loss: -0.6372 - acc: 0.0892
# Epoch 17/25
# 2712/2712 [==============================] - 0s 16us/step - loss: -0.7176 - acc: 0.0892
# Epoch 18/25
# 2712/2712 [==============================] - 0s 14us/step - loss: -0.7969 - acc: 0.0892
# Epoch 19/25
# 2712/2712 [==============================] - 0s 17us/step - loss: -0.8752 - acc: 0.0892
# Epoch 20/25
# 2712/2712 [==============================] - 0s 17us/step - loss: -0.9525 - acc: 0.0892
# Epoch 21/25
# 2712/2712 [==============================] - 0s 17us/step - loss: -1.0289 - acc: 0.0892
# Epoch 22/25
# 2712/2712 [==============================] - 0s 17us/step - loss: -1.1043 - acc: 0.0892
# Epoch 23/25
# 2712/2712 [==============================] - 0s 16us/step - loss: -1.1789 - acc: 0.0892
# Epoch 24/25
# 2712/2712 [==============================] - 0s 14us/step - loss: -1.2527 - acc: 0.0892
# Epoch 25/25
# 2712/2712 [==============================] - 0s 14us/step - loss: -1.3256 - acc: 0.0892

# %%
model.accuracy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-8985af591bd6> in <module>
# ----> 1 model.accuracy()
#
# AttributeError: 'Sequential' object has no attribute 'accuracy'
