# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('phl_hec_all_confirmed.csv')

# %%
dataset.head()
# Out:
#             P. Name P. Name Kepler  P. Name KOI P. Zone Class P. Mass Class  \
# 0       1RXS 1609 b            NaN          NaN          Cold        Jovian
# 1    1SWASP J1407 b            NaN          NaN          Cold        Jovian
# 2  2M 0103-55(AB) b            NaN          NaN          Cold        Jovian
# 3      2M 0122-24 b            NaN          NaN          Cold        Jovian
# 4      2M 0219-39 b            NaN          NaN          Cold        Jovian
#
#   P. Composition Class P. Atmosphere Class P. Habitable Class  \
# 0                  gas       hydrogen-rich      non-habitable
# 1                  gas       hydrogen-rich      non-habitable
# 2                  gas       hydrogen-rich      non-habitable
# 3                  gas       hydrogen-rich      non-habitable
# 4                  gas       hydrogen-rich      non-habitable
#
#    P. Min Mass (EU)  P. Mass (EU)  ...  P. Int ESI  P. Surf ESI  P. ESI  \
# ...

# %%
dataset = dataset.fillna(0)

# %%
dataset.to_csv('new_data.csv')

# %%
dataset.columns
# Out:
# Index(['P. Name', 'P. Name Kepler', 'P. Name KOI', 'P. Zone Class',
#        'P. Mass Class', 'P. Composition Class', 'P. Atmosphere Class',
#        'P. Habitable Class', 'P. Min Mass (EU)', 'P. Mass (EU)',
#        'P. Max Mass (EU)', 'P. Radius (EU)', 'P. Density (EU)',
#        'P. Gravity (EU)', 'P. Esc Vel (EU)', 'P. SFlux Min (EU)',
#        'P. SFlux Mean (EU)', 'P. SFlux Max (EU)', 'P. Teq Min (K)',
#        'P. Teq Mean (K)', 'P. Teq Max (K)', 'P. Ts Min (K)', 'P. Ts Mean (K)',
#        'P. Ts Max (K)', 'P. Surf Press (EU)', 'P. Mag', 'P. Appar Size (deg)',
#        'P. Period (days)', 'P. Sem Major Axis (AU)', 'P. Eccentricity',
#        'P. Mean Distance (AU)', 'P. Inclination (deg)', 'P. Omega (deg)',
#        'S. Name', 'S. Name HD', 'S. Name HIP', 'S. Constellation', 'S. Type',
#        'S. Mass (SU)', 'S. Radius (SU)', 'S. Teff (K)', 'S. Luminosity (SU)',
#        'S. [Fe/H]', 'S. Age (Gyrs)', 'S. Appar Mag', 'S. Distance (pc)',
# ...

# %%
dataset["P. Habitable Class"].value_counts()
# Out:
# non-habitable        3820
# mesoplanet             31
# psychroplanet          18
# hypopsychroplanet       3
# thermoplanet            3
# Name: P. Habitable Class, dtype: int64

# %%
cleanup_nums = {"P. Zone Class":     {"Cold": 1, "Hot": 2, "Warm": 3 },
                "P. Mass Class": {"Jovian": 1, "Superterran": 2, "Neptunian": 3, "Terran": 4,
                                  "Subterran": 5, "Mercurian":6},
               "P. Composition Class": {"gas": 1, "rocky-iron": 2, "rocky-water": 3, "water-gas": 4, "iron": 5},
               "P. Atmosphere Class": {"metals-rich": 1, "hydrogen-rich": 2, "no-atmosphere": 3},
               "P. Habitable Class": {"non-habitable": 1, "mesoplanet": 2, "psychroplanet": 3, "hypopyschroplanet": 4, "thermoplanet": 5}}

# %%
dataset.replace(cleanup_nums, inplace=True)

# %%
dataset.columns
# Out:
# Index(['P. Name', 'P. Name Kepler', 'P. Name KOI', 'P. Zone Class',
#        'P. Mass Class', 'P. Composition Class', 'P. Atmosphere Class',
#        'P. Habitable Class', 'P. Min Mass (EU)', 'P. Mass (EU)',
#        'P. Max Mass (EU)', 'P. Radius (EU)', 'P. Density (EU)',
#        'P. Gravity (EU)', 'P. Esc Vel (EU)', 'P. SFlux Min (EU)',
#        'P. SFlux Mean (EU)', 'P. SFlux Max (EU)', 'P. Teq Min (K)',
#        'P. Teq Mean (K)', 'P. Teq Max (K)', 'P. Ts Min (K)', 'P. Ts Mean (K)',
#        'P. Ts Max (K)', 'P. Surf Press (EU)', 'P. Mag', 'P. Appar Size (deg)',
#        'P. Period (days)', 'P. Sem Major Axis (AU)', 'P. Eccentricity',
#        'P. Mean Distance (AU)', 'P. Inclination (deg)', 'P. Omega (deg)',
#        'S. Name', 'S. Name HD', 'S. Name HIP', 'S. Constellation', 'S. Type',
#        'S. Mass (SU)', 'S. Radius (SU)', 'S. Teff (K)', 'S. Luminosity (SU)',
#        'S. [Fe/H]', 'S. Age (Gyrs)', 'S. Appar Mag', 'S. Distance (pc)',
# ...

# %%
dataset.to_csv('new_data.csv')
dataset.columns
# Out:
# Index(['P. Name', 'P. Name Kepler', 'P. Name KOI', 'P. Zone Class',
#        'P. Mass Class', 'P. Composition Class', 'P. Atmosphere Class',
#        'P. Habitable Class', 'P. Min Mass (EU)', 'P. Mass (EU)',
#        'P. Max Mass (EU)', 'P. Radius (EU)', 'P. Density (EU)',
#        'P. Gravity (EU)', 'P. Esc Vel (EU)', 'P. SFlux Min (EU)',
#        'P. SFlux Mean (EU)', 'P. SFlux Max (EU)', 'P. Teq Min (K)',
#        'P. Teq Mean (K)', 'P. Teq Max (K)', 'P. Ts Min (K)', 'P. Ts Mean (K)',
#        'P. Ts Max (K)', 'P. Surf Press (EU)', 'P. Mag', 'P. Appar Size (deg)',
#        'P. Period (days)', 'P. Sem Major Axis (AU)', 'P. Eccentricity',
#        'P. Mean Distance (AU)', 'P. Inclination (deg)', 'P. Omega (deg)',
#        'S. Name', 'S. Name HD', 'S. Name HIP', 'S. Constellation', 'S. Type',
#        'S. Mass (SU)', 'S. Radius (SU)', 'S. Teff (K)', 'S. Luminosity (SU)',
#        'S. [Fe/H]', 'S. Age (Gyrs)', 'S. Appar Mag', 'S. Distance (pc)',
# ...

# %%
dataset = dataset.drop(['P. Name Kepler', 'P. Name KOI', 'P. Disc. Year', 'Unnamed: 68', 'S. Name'], axis = 1)

# %%
dataset.columns
# Out:
# Index(['P. Name', 'P. Zone Class', 'P. Mass Class', 'P. Composition Class',
#        'P. Atmosphere Class', 'P. Habitable Class', 'P. Min Mass (EU)',
#        'P. Mass (EU)', 'P. Max Mass (EU)', 'P. Radius (EU)', 'P. Density (EU)',
#        'P. Gravity (EU)', 'P. Esc Vel (EU)', 'P. SFlux Min (EU)',
#        'P. SFlux Mean (EU)', 'P. SFlux Max (EU)', 'P. Teq Min (K)',
#        'P. Teq Mean (K)', 'P. Teq Max (K)', 'P. Ts Min (K)', 'P. Ts Mean (K)',
#        'P. Ts Max (K)', 'P. Surf Press (EU)', 'P. Mag', 'P. Appar Size (deg)',
#        'P. Period (days)', 'P. Sem Major Axis (AU)', 'P. Eccentricity',
#        'P. Mean Distance (AU)', 'P. Inclination (deg)', 'P. Omega (deg)',
#        'S. Name HD', 'S. Name HIP', 'S. Constellation', 'S. Type',
#        'S. Mass (SU)', 'S. Radius (SU)', 'S. Teff (K)', 'S. Luminosity (SU)',
#        'S. [Fe/H]', 'S. Age (Gyrs)', 'S. Appar Mag', 'S. Distance (pc)',
#        'S. RA (hrs)', 'S. DEC (deg)', 'S. Mag from Planet',
# ...

# %%
dataset.select_dtypes(include=['object']).copy()
# Out:
#                P. Name P. Habitable Class P. SFlux Min (EU)  \
# 0          1RXS 1609 b                  1          4.08E-06
# 1       1SWASP J1407 b                  1        0.02166914
# 2     2M 0103-55(AB) b                  1          3.96E-06
# 3         2M 0122-24 b                  1          1.03E-05
# 4         2M 0219-39 b                  1          2.37E-07
# ...                ...                ...               ...
# 3870         YBP1194 b                  1          124.7097
# 3871         YBP1514 b                  1          120.2813
# 3872          YZ Cet b                  1          9.110547
# 3873          YZ Cet c                  1          4.674975
# 3874          YZ Cet d                  1          2.268338
#
#      P. SFlux Mean (EU) P. SFlux Max (EU) S. Name HD S. Name HIP  \
# 0              4.08E-06          4.08E-06          0           0
# 1            0.02166914        0.02166914          0           0
# ...

# %%
dataset["P. Disc. Method"].value_counts()
# Out:
# Primary Transit    1490
# Transit            1398
# Radial Velocity     750
# Imaging              91
# Microlensing         78
# Pulsar               29
# Other                14
# transit              13
# radial velocity       7
# TTV                   4
# Astrometry            1
# Name: P. Disc. Method, dtype: int64

# %%
dataset.to_csv('new_data.csv')

# %%
dataset
# Out:
#                P. Name  P. Zone Class  P. Mass Class  P. Composition Class  \
# 0          1RXS 1609 b              1              1                     1
# 1       1SWASP J1407 b              1              1                     1
# 2     2M 0103-55(AB) b              1              1                     1
# 3         2M 0122-24 b              1              1                     1
# 4         2M 0219-39 b              1              1                     1
# ...                ...            ...            ...                   ...
# 3870         YBP1194 b              2              1                     1
# 3871         YBP1514 b              2              1                     1
# 3872          YZ Cet b              2              4                     2
# 3873          YZ Cet c              2              4                     2
# 3874          YZ Cet d              2              4                     2
#
# ...

# %%
data = dataset.select_dtypes(['number'])

# %%
data.to_csv('./Naive Bayes/new_data_numeric.csv')

# %%
data
# Out:
#       P. Zone Class  P. Mass Class  P. Composition Class  P. Atmosphere Class  \
# 0                 1              1                     1                    2
# 1                 1              1                     1                    2
# 2                 1              1                     1                    2
# 3                 1              1                     1                    2
# 4                 1              1                     1                    2
# ...             ...            ...                   ...                  ...
# 3870              2              1                     1                    1
# 3871              2              1                     1                    1
# 3872              2              4                     2                    1
# 3873              2              4                     2                    1
# 3874              2              4                     2                    1
#
# ...

# %%
data.drop([0], axis = 0)
# Out:
#       P. Zone Class  P. Mass Class  P. Composition Class  P. Atmosphere Class  \
# 1                 1              1                     1                    2
# 2                 1              1                     1                    2
# 3                 1              1                     1                    2
# 4                 1              1                     1                    2
# 5                 1              1                     1                    2
# ...             ...            ...                   ...                  ...
# 3870              2              1                     1                    1
# 3871              2              1                     1                    1
# 3872              2              4                     2                    1
# 3873              2              4                     2                    1
# 3874              2              4                     2                    1
#
# ...

# %%
import seaborn as sns
sns.heatmap(data)
