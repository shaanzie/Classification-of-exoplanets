# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('phl_hec_all_confirmed.csv')

# %%
dataset
# Out:
#                P. Name P. Name Kepler  P. Name KOI P. Zone Class  \
# 0          1RXS 1609 b            NaN          NaN          Cold
# 1       1SWASP J1407 b            NaN          NaN          Cold
# 2     2M 0103-55(AB) b            NaN          NaN          Cold
# 3         2M 0122-24 b            NaN          NaN          Cold
# 4         2M 0219-39 b            NaN          NaN          Cold
# ...                ...            ...          ...           ...
# 3870         YBP1194 b            NaN          NaN           Hot
# 3871         YBP1514 b            NaN          NaN           Hot
# 3872          YZ Cet b            NaN          NaN           Hot
# 3873          YZ Cet c            NaN          NaN           Hot
# 3874          YZ Cet d            NaN          NaN           Hot
#
#      P. Mass Class P. Composition Class P. Atmosphere Class  \
# 0           Jovian                  gas       hydrogen-rich
# 1           Jovian                  gas       hydrogen-rich
# ...

# %%
dataset = dataset.drop(['P. Name Kepler','P. Name KOI', 'P. Max Mass (EU)', 'Unnamed: 68', 'P. SPH'],axis = 1)

# %%
dataset.fillna(0)
# Out:
#                P. Name P. Zone Class P. Mass Class P. Composition Class  \
# 0          1RXS 1609 b          Cold        Jovian                  gas
# 1       1SWASP J1407 b          Cold        Jovian                  gas
# 2     2M 0103-55(AB) b          Cold        Jovian                  gas
# 3         2M 0122-24 b          Cold        Jovian                  gas
# 4         2M 0219-39 b          Cold        Jovian                  gas
# ...                ...           ...           ...                  ...
# 3870         YBP1194 b           Hot        Jovian                  gas
# 3871         YBP1514 b           Hot        Jovian                  gas
# 3872          YZ Cet b           Hot        Terran           rocky-iron
# 3873          YZ Cet c           Hot        Terran           rocky-iron
# 3874          YZ Cet d           Hot        Terran           rocky-iron
#
#      P. Atmosphere Class P. Habitable Class  P. Min Mass (EU)  P. Mass (EU)  \
# ...

# %%
dataset.to_csv('new_data.csv')

# %%
dataset.dtypes
# Out:
# P. Name                 object
# P. Zone Class           object
# P. Mass Class           object
# P. Composition Class    object
# P. Atmosphere Class     object
#                          ...
# P. Habitable             int64
# P. Hab Moon              int64
# P. Confirmed             int64
# P. Disc. Method         object
# P. Disc. Year           object
# Length: 64, dtype: object

# %%
obj_df = dataset.select_dtypes(include=['object']).copy()
obj_df
# Out:
#                P. Name P. Zone Class P. Mass Class P. Composition Class  \
# 0          1RXS 1609 b          Cold        Jovian                  gas
# 1       1SWASP J1407 b          Cold        Jovian                  gas
# 2     2M 0103-55(AB) b          Cold        Jovian                  gas
# 3         2M 0122-24 b          Cold        Jovian                  gas
# 4         2M 0219-39 b          Cold        Jovian                  gas
# ...                ...           ...           ...                  ...
# 3870         YBP1194 b           Hot        Jovian                  gas
# 3871         YBP1514 b           Hot        Jovian                  gas
# 3872          YZ Cet b           Hot        Terran           rocky-iron
# 3873          YZ Cet c           Hot        Terran           rocky-iron
# 3874          YZ Cet d           Hot        Terran           rocky-iron
#
#      P. Atmosphere Class P. Habitable Class P. SFlux Min (EU)  \
# ...

# %%
obj_df[obj_df.isnull().any(axis=1)]
# Out:
#                P. Name P. Zone Class P. Mass Class P. Composition Class  \
# 0          1RXS 1609 b          Cold        Jovian                  gas
# 1       1SWASP J1407 b          Cold        Jovian                  gas
# 2     2M 0103-55(AB) b          Cold        Jovian                  gas
# 3         2M 0122-24 b          Cold        Jovian                  gas
# 4         2M 0219-39 b          Cold        Jovian                  gas
# ...                ...           ...           ...                  ...
# 3870         YBP1194 b           Hot        Jovian                  gas
# 3871         YBP1514 b           Hot        Jovian                  gas
# 3872          YZ Cet b           Hot        Terran           rocky-iron
# 3873          YZ Cet c           Hot        Terran           rocky-iron
# 3874          YZ Cet d           Hot        Terran           rocky-iron
#
#      P. Atmosphere Class P. Habitable Class P. SFlux Min (EU)  \
# ...

# %%
dataset = dataset.dropna(axis=1)
dataset.to_csv('new_data.csv')

# %%
obj_df["P. Habitable Class"].value_counts()
# Out:
# non-habitable        3820
# mesoplanet             31
# psychroplanet          18
# hypopsychroplanet       3
# thermoplanet            3
# Name: P. Habitable Class, dtype: int64

# %%
cleanup_nums = {"P. Zone Class":     {"Cold": 1, "Hot": 2, "Warm": 3 },
                "P. Mass Class": {"Jovian": 1, "Superterran": 2, "Neptunian": 3, "Terran": 4,
                                  "Subterran": 5, "Mercurian":6},
               "P. Composition Class": {"gas": 1, "rocky-iron": 2, "rocky-water": 3, "water-gas": 4, "iron": 5},
               "P. Atmosphere Class": {"metals-rich": 1, "hydrogen-rich": 2, "no-atmosphere": 3},
               "P. Habitable Class": {"non-habitable": 1, "mesoplanet": 2, "psychroplanet": 3, "hypopyschroplanet": 4, "thermoplanet": 5}}

# %%
obj_df.replace(cleanup_nums, inplace=True)

# %%
obj_df = obj_df.drop(['S. Name HD', 'S. Name HIP'], axis = 1)

# %%
obj_df.to_csv('new_data.csv')

# %%
obj_df
# Out:
#                P. Name  P. Zone Class  P. Mass Class  P. Composition Class  \
# 0          1RXS 1609 b            1.0            1.0                   1.0
# 1       1SWASP J1407 b            1.0            1.0                   1.0
# 2     2M 0103-55(AB) b            1.0            1.0                   1.0
# 3         2M 0122-24 b            1.0            1.0                   1.0
# 4         2M 0219-39 b            1.0            1.0                   1.0
# ...                ...            ...            ...                   ...
# 3870         YBP1194 b            2.0            1.0                   1.0
# 3871         YBP1514 b            2.0            1.0                   1.0
# 3872          YZ Cet b            2.0            4.0                   2.0
# 3873          YZ Cet c            2.0            4.0                   2.0
# 3874          YZ Cet d            2.0            4.0                   2.0
#
#       P. Atmosphere Class P. Habitable Class P. SFlux Min (EU)  \
# ...
